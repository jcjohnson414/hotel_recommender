# %%
import pandas as pd
import numpy as np

pd.set_option('max_columns', None)
pd.set_option('max_rows', None)

# %%
ihg = pd.read_csv('all_ihg_descriptions.csv')

# %%
ihg.shape
# Out:
# (3854, 11)

# %%
test = ihg[ihg['rating'].isnull()]
test
# Out:
#       Unnamed: 0                                               name  \
# 3650        3650                      Kimpton Hotel Palomar Phoenix
# 3658        3658                          Kimpton Shorebreak Resort
# 3664        3664                         Kimpton Rowan Palm Springs
# 3669        3669                    Kimpton Sir Francis Drake Hotel
# 3670        3670                             Kimpton Buchanan Hotel
# 3672        3672                                Kimpton Alton Hotel
# 3673        3673                               Kimpton Everly Hotel
# 3674        3674                             Kimpton Hotel Wilshire
# 3675        3675                              Kimpton La Peer Hotel
# 3676        3676                Kimpton Hotel Palomar Beverly Hills
# 3679        3679                               Kimpton Canary Hotel
# 3680        3680                                   Kimpton Goodland
# 3681        3681                    Kimpton Hotel Palomar San Diego
# ...

# %%
ihg = ihg2[~ihg2['rating'].isnull()]

# %%
ihg.shape
# Out:
# (3763, 11)

# %%
test.shape
# Out:
# (91, 11)

# %%
ihg.to_csv('ihg_ratings.csv')
test.to_csv('ihg_missing_ratings.csv')
