# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests
import json
from selenium.webdriver import Chrome
from selenium import webdriver
from datetime import datetime
import time

pd.set_option('max_columns', None)
pd.set_option('max_rows', None)

# %%
dataframe = pd.read_csv('ihg_urls.csv')

# %%
dataframe[dataframe['name'].str.contains('Crowne Plaza')]
# Out:
#       Unnamed: 0                                               name  \
# 84            84                     Crowne Plaza Anchorage-Midtown
# 100          100  Crowne Plaza Hotels & Resorts Phoenix - Chandl...
# 112          112                 Crowne Plaza Phoenix Airport - PHX
# 168          168                           Crowne Plaza Little Rock
# 219          219                      Crowne Plaza Memphis Downtown
# 225          225                          Crowne Plaza Memphis East
# 244          244                  Crowne Plaza Concord/Walnut Creek
# 265          265              Crowne Plaza Costa Mesa Orange County
# 276          276           Crowne Plaza Los Angeles-Commerce Casino
# 284          284              Crowne Plaza Los Angeles Harbor Hotel
# 300          300              Crowne Plaza Redondo Beach And Marina
# 301          301                   Crowne Plaza Los Angeles Airport
# 315          315                  Crowne Plaza Sacramento Northeast
# 339          339                 Crowne Plaza Foster City-San Mateo
# 342          342                 Crowne Plaza San Francisco Airport
# 347          347                             Crowne Plaza Palo Alto
# 349          349         Crowne Plaza Silicon Valley N - Union City
# 369          369               Crowne Plaza San Jose-Silicon Valley
# 408          408                         Crowne Plaza Ventura Beach
# 427          427            Crowne Plaza San Diego - Mission Valley
# 519          519         Crowne Plaza Denver Airport Convention Ctr
# 528          528                                Crowne Plaza Denver
# 601          601                              Crowne Plaza Stamford
# 605          605                               Crowne Plaza Danbury
# 611          611                 Crowne Plaza White Plains-Downtown
# 636          636                             Crowne Plaza Englewood
# 649          649             Crowne Plaza JFK Airport New York City
# 658          658                      Crowne Plaza Wilmington North
# 677          677        Crowne Plaza Philadelphia - King of Prussia
# 679          679              Crowne Plaza Philadelphia-Cherry Hill
# 706          706         Crowne Plaza Crystal City-Washington, D.C.
# 725          725             Crowne Plaza Greenbelt - Washington DC
# 735          735                        Crowne Plaza Dulles Airport
# 754          754                             Crowne Plaza Annapolis
# 770          770                      Crowne Plaza Orlando-Downtown
# 775          775              Crowne Plaza Orlando - Universal Blvd
# 791          791            Crowne Plaza Orlando - Lake Buena Vista
# 823          823         Crowne Plaza Ft. Lauderdale Airport/Cruise
# 844          844        Crowne Plaza Fort Myers At Bell Tower Shops
# 898          898                  Crowne Plaza Melbourne-Oceanfront
# 924          924           Crowne Plaza South Beach - Z Ocean Hotel
# 935          935                         Crowne Plaza Miami Airport
# 973          973            Crowne Plaza Jacksonville Airport/I-95N
# 993          993                    Crowne Plaza Key West-La Concha
# 1033        1033          Crowne Plaza Atlanta Perimeter at Ravinia
# 1046        1046                     Crowne Plaza Atlanta - Midtown
# 1047        1047                    Crowne Plaza Atlanta - Norcross
# 1074        1074                       Crowne Plaza Atlanta-Airport
# 1092        1092           Crowne Plaza Atlanta SW - Peachtree City
# 1093        1093                         Crowne Plaza North Augusta
# 1231        1231                    Crowne Plaza Chicago-Northbrook
# 1238        1238                 Crowne Plaza Lombard Downers Grove
# 2702  https://www.ihg.com/crowneplaza/hotels/us/en/d...
# 2737  https://www.ihg.com/crowneplaza/hotels/us/en/c...
# 2748  https://www.ihg.com/crowneplaza/hotels/us/en/c...
# 2824  https://www.ihg.com/crowneplaza/hotels/us/en/t...
# 2882  https://www.ihg.com/crowneplaza/hotels/us/en/l...
# 2888  https://www.ihg.com/crowneplaza/hotels/us/en/p...
# 2930  https://www.ihg.com/crowneplaza/hotels/us/en/p...
# 2967  https://www.ihg.com/crowneplaza/hotels/us/en/h...
# 2998  https://www.ihg.com/crowneplaza/hotels/us/en/r...
# 3022  https://www.ihg.com/crowneplaza/hotels/us/en/g...
# 3050  https://www.ihg.com/crowneplaza/hotels/us/en/n...
# 3103  https://www.ihg.com/crowneplaza/hotels/us/en/k...
# 3179  https://www.ihg.com/crowneplaza/hotels/us/en/a...
# 3209  https://www.ihg.com/crowneplaza/hotels/us/en/d...
# 3215  https://www.ihg.com/crowneplaza/hotels/us/en/d...
# 3232  https://www.ihg.com/crowneplaza/hotels/us/en/a...
# 3294  https://www.ihg.com/crowneplaza/hotels/us/en/h...
# 3305  https://www.ihg.com/crowneplaza/hotels/us/en/h...
# 3312  https://www.ihg.com/crowneplaza/hotels/us/en/h...
# 3327  https://www.ihg.com/crowneplaza/hotels/us/en/h...
# 3371  https://www.ihg.com/crowneplaza/hotels/us/en/a...
# 3492  https://www.ihg.com/crowneplaza/hotels/us/en/s...
# 3752  https://www.ihg.com/crowneplaza/hotels/us/en/v...
# 3804  https://www.ihg.com/crowneplaza/hotels/us/en/s...
# 3815  https://www.ihg.com/crowneplaza/hotels/us/en/s...
# 3882  https://www.ihg.com/crowneplaza/hotels/us/en/w...
# 3893  https://www.ihg.com/crowneplaza/hotels/us/en/m...

# %%
def get_hotels(dataframe):
#     start = string
#     url = "https://www.ihg.com/destinations/us/en/united-states-hotels"
#     res = requests.get(url)
#     soup = BeautifulSoup(res.content, 'lxml')
#     states = soup.find('div',{'class' : 'countryListingContainer col-xs-12'})

#     states_list =[]
#     for x in states.find_all('li'):
#         state = {}
#         state['name'] = x.find('a').text.strip()[:-7]
#         state['url'] = x.find('a').attrs['href']
#         states_list.append(state)
#     states_df = pd.DataFrame(states_list)
#     states_df1 = states_df
        
#     cities_list =[]
#     counter = 0
#     for index, row in states_df1.iterrows():
#         state_name = row['name']
#         state_url = row['url']
#         state_res = requests.get(state_url)
#         state_soup = BeautifulSoup(state_res.content, 'lxml')
#         cities = state_soup.find('div',{'class' : 'countryListingContainer col-xs-12'})
#         for x in cities.find_all('li'):
#             city = {}
#             city['name'] = x.find('a').text.strip()[:-7]
#             city['url'] = x.find('a').attrs['href']
#             cities_list.append(city)
#         if (counter + 1) % 1 == 0:
#             print(f"Completed {state_name} at {datetime.now()}.")
#         counter += 1
#     cities_df = pd.DataFrame(cities_list)
# #     return cities_df

# # -----------------------------------------------------------------------------------------

#     counter = 0
#     items_list = []
#     for index, row in cities_df.iterrows(): 
#         city = row['name']
#         city_url = row['url']
#     #         city = city.lower()
#     #         city = city.replace(' ','-')
#     #         url = 'https://www.ihg.com/destinations/us/en/united-states/'
#     #         state_url = url + state1

#         try:
#             city_url = city_url
#     #             city_url = 'https://www.ihg.com/destinations/us/en/united-states/alabama/alabaster-hotels'
#             res = requests.get(city_url)
#     #             time.sleep(2)
#             soup = BeautifulSoup(res.content, 'lxml')
#             hotel_soup = soup.find('div', {'class' : "row row-hotel-list"})
#     #             print(hotel_soup)
#             for x in hotel_soup.find_all('p'):
#                 for z in x.find_all('a'):
#     #                     print(z)
#                     items = {}
#                     items['name'] = z.text
#                     items['url'] = z.attrs['href']
#                     if items not in items_list:
#                         items_list.append(items)
#                     else:
#                         pass 

#         except:
#             pass
#         if (counter + 1) % 1 == 0:
#             print(f"Completed {city} at {datetime.now()}.")
#         counter += 1
#     #     return items_list
#     dataframe = pd.DataFrame(items_list)
#     dataframe = dataframe.drop_duplicates()    

# #     new_list = []
# #     for index, row in dataframe.iterrows():
# #         name = row['name']
# #         url = row['url']
# #         xyz = {}
# #         if state1 in url:
# #             xyz['name'] = name
# #             xyz['url'] = url
# #             new_list.append(xyz)
# #     dataframe = pd.DataFrame(new_list)
#     print('='*40)
#     print(f"The shape of the hotel dataframe is {dataframe.shape}.")
#     print('='*40)
#     dataframe.to_csv('ihg_urls.csv')

# ----------------------------------------------------------------------------- 
    dataframe = dataframe
    descriptions = []
    addresses = []
    ratings = []
    missing = []
    counter = 0
    for index, row in dataframe.iterrows():
        if 'InterContinental' in row['name'] or 'Avid' in row['name']:
            name = row['name']
            url = row['url']
        #         print(name)
        #         print(url)
#             try: # FOR HOLIDAY INN EXPRESS
#                 res = requests.get(url)
#                 soup = BeautifulSoup(res.content, 'lxml')
#                 itemaddress = soup.find('div',{'itemprop' : 'address'})
#                 for x in itemaddress.find_all('p'):
#                     address = {}
#                     address['name'] = name
#                     address['url'] = url
#                     address['street'] = x.find_all('span')[0].text.strip()
#                     address['locality'] = x.find_all('span')[1].text.strip()
#                     address['region'] = x.find_all('span')[2].text.strip()
#                     address['postalcode'] = x.find_all('span')[3].text.strip()
#                     addresses.append(address)
#                 itemdescription = soup.find_all('div', {'class' : "wl-txt-sec"})
#                 for x in itemdescription:
#                     description = {}
#                     description['name'] = name
#                     description['description'] = x.text
#                     descriptions.append(description)
#                     itemrating = soup.find('div',{'class' : 'reviews responsiveReviews'})
#                     rating = {}
#                     rating['name'] = name
#                     rating['rating'] = itemrating.find_all('span')[1].text
#                     ratings.append(rating)
#             except:
#                 try: # FOR HOLIDAY INN
#                     res = requests.get(url)
#                     soup = BeautifulSoup(res.content, 'lxml')
#                     itemaddress = soup.find('div',{'itemprop' : 'address'})
#                     fulladdress = itemaddress.find_all('p')
#                     address = {}
#                     address['name'] = name
#                     address['url'] = url
#                     address['street'] = fulladdress[0].text.strip()
#                     city_state = fulladdress[4].text.strip().split(',')
#                     address['locality'] =city_state[0]
#                     address['region']= city_state[1].replace('\xa0','')
#                     address['postalcode'] = fulladdress[5].text.strip()
#                     addresses.append(address)
#                     itemdescription = soup.find_all('div', {'class' : "wl-txt-sec"})
#                     for x in itemdescription:
#                         description = {}
#                         description['name'] = name
#                         description['description'] = x.text
#                         descriptions.append(description)
#                     itemrating = soup.find('div',{'class' : 'reviews responsiveReviews'})
#                     rating = {}
#                     rating['name'] = name
#                     rating['rating'] = itemrating.find_all('span')[1].text
#                     ratings.append(rating)

#                 except:
#                     try: # FOR CANDLEWOOD SUITES
#                         res = requests.get(url)
#                         soup = BeautifulSoup(res.content, 'lxml')
#                         itemaddress = soup.find('p',{'itemprop' : 'address'})
#                         fulladdress = itemaddress.find_all('span')
#                         address = {}
#                         address['name'] = name
#                         address['url'] = url
#                         address['street'] = fulladdress[0].text.strip()
#                         address['locality'] =fulladdress[1].text.strip()
#                         address3 = fulladdress[2].text.strip()
#                         address['region']= address3[:-20]
#                         address['postalcode'] = address3[-19:-14]
#                         address['address3'] = address3
#                         addresses.append(address)
#                         itemdescription = soup.find_all('div', {'class' : "wl-txt-sec"})
#                         for x in itemdescription:
#                             description = {}
#                             description['name'] = name
#                             description['description'] = x.text
#                             descriptions.append(description)
#                         itemrating = soup2.find('div',{'class' : 'show-rating'})
#                         rating = {}
#                         rating['name'] = name
#                         rating['rating'] = itemrating.find_all('span')[0].text
#                         ratings.append(rating)
#                     except:
#                         try: # FOR HOTEL INDIGO
#                             res = requests.get(url)
#                             soup = BeautifulSoup(res.content, 'lxml')                        
#                             itemaddress = soup.find('span',{'itemprop' : 'address'})
#                             fulladdress = itemaddress.find_all('span')
#                             address = {}
#                             address['name'] = name
#                             address['url'] = url
#                             address['street'] = fulladdress[0].text.strip()
#                             address['locality'] =fulladdress[1].text.strip()
#                             address['region'] =fulladdress[2].text.strip()
#                             address['postalcode'] =fulladdress[3].text.strip()
#                             addresses.append(address)
#                             description = {}
#                             full_description = ""
#                             descriptionsoup = soup.find('div', {'class' : "desc"})
#                             for x in descriptionsoup('p'):
#                                 x = x.text
#                                 x = " " + x
#                                 full_description += (x)
#                             extra_description = soup.find('div', {'class' : "in-highlight"})
#                             for x in extra_description('div', {'class' : 'highlight-desc'}):
#                                 x = x.text.strip()
#                                 x = " " + x
#                                 full_description += x
#                             full_description = full_description.replace('\n','').replace('\t','').replace('\xa0', '').replace('Learn More', '').strip()
#                             description['name'] = name
#                             description['description'] = full_description
#                             descriptions.append(description)
#                             itemrating = soup.find('div',{'class' : 'reviews responsiveReviews'})
#                             rating = {}
#                             rating['name'] = name
#                             rating['rating'] = itemrating.find_all('span')[1].text
#                             ratings.append(rating)
#                             print(address)
#                             print(description)
#                             print(rating)
#                             print()
#                             print('='*50)
#                             print(counter)
#                             print()

#                         except:
#                             try: # For Kimpton Hotels
#                                 res = requests.get(url)
#                                 soup = BeautifulSoup(res.content, 'lxml')
#                                 itemaddress = soup.find('div',{'class' : 'desc'})
#                                 itemaddress = str(itemaddress).split('<br/>')
#                                 newaddress = []
#                                 address = {}
#                                 for x in itemaddress:
#                                     x = x.replace('<div class="desc">\n<span class="visible-content">','').replace('</span>','')
#                                     newaddress.append(x)
#                                 address['name'] = name
#                                 address['url'] = url
#                                 address['street'] = newaddress[0]
#                                 address['locality'] = newaddress[1][:-8]
#                                 address['region'] = newaddress[1][-8:-5]
#                                 address['postalcode'] = newaddress[1][-5:]
#                                 addresses.append(address)
                                
#                                 descriptionsoup = soup.find_all('div',{'class' : 'desc'})
#                                 description = {}
#                                 desc = ''
#                                 for x in descriptionsoup[1:]:
#                                     x = x.text.strip()
#                                     x = x.replace('Learn More', '').replace('\t','').replace('\n','')
#                                     x = " " + x
#                                     desc += x
#                                 description['name'] = name
#                                 description['description'] = desc
#                                 descriptions.append(description)
                                
#                                 rating = {}
#                                 rating['name'] = name
#                                 rating['rating'] = 'N/A'
#                                 ratings.append(rating)
#                                 print(address)
#                                 print(description)
#                                 print(rating)
#                                 print()
#                                 print('='*50)
#                                 print(counter)
#                                 print()

#                             except:
#                                 try: # For Crowne Plaza
#                                     res = requests.get(url)
#                                     soup = BeautifulSoup(res.content, 'lxml')                                
#                                     itemaddress = soup.find('div',{'class' : 'new-hinfo-address'})
#                                     hoteladdress = {}
#                                     newaddress = []
#                                     for x in itemaddress.find_all('p'):
#                                         address = x.find_all('a')[0].text
#                                         address = address.split('|')
#                                         for x in address:
#                                             x = x.replace('\n','')
#                                             x = x.replace('\t','')
#                                             newaddress.append(x)
#                                     newaddress[0] = newaddress[0].split(',')
#                                     hoteladdress['name'] = name
#                                     hoteladdress['url'] = url
#                                     hoteladdress['street'] = newaddress[0][0].strip().replace('\n','').replace('\t','')
#                                     hoteladdress['locality'] = newaddress[0][1].strip()
#                                     hoteladdress['region'] = newaddress[1].strip()
#                                     hoteladdress['postalcode'] = newaddress[2].strip()
#                                     addresses.append(hoteladdress)
                                    
#                                     itemdescription = soup.find_all('div', {'class' : 'wl-txt-sec'})
#                                     description = {}
#                                     description['name'] = name
#                                     description['description'] = itemdescription[0].text
#                                     descriptions.append(description)
                                    
#                                     itemrating = soup.find('div', {'class' : 'reviews responsiveReviews'})
#                                     rating = {}
#                                     rating['name'] = name
#                                     rating['rating'] = itemrating.find_all('p')[0].text
#                                     ratings.append(rating)
#                                     print(address)
#                                     print(description)
#                                     print(rating)
#                                     print()
#                                     print('='*50)
#                                     print(counter)
#                                     print()

#                                 except:
            try: # for InterContinental
                res = requests.get(url)
                soup = BeautifulSoup(res.content, 'lxml')        
                itemrating8 = soup.find_all('div',{'class' : 'address'})    
                hoteladdress = {}
                address = []
                for x in itemrating8:
                    x = x.find_all('span')[0].text
                    x = x.split(',')
                    for x in x:
                        address.append(x)
                hoteladdress['name'] = name
                hoteladdress['url'] = url
                hoteladdress['street'] = address[0].split(':')[0].strip()
                hoteladdress['locality'] = address[1].strip()
                hoteladdress['region'] = address[0].split(':')[1].strip()
                hoteladdress['postalcode'] = address[2].strip()
                addresses.append(hoteladdress)

                itemrating9 = soup.find_all('div',{'class' : 'hotel-description'})
                description = {}
                description['name'] = name
                description['description'] = itemrating9[0].text
                descriptions.append(description)

                rating = {}
                rating['name'] = name
                rating['rating'] = 'N/A'
                ratings.append(rating)
                print(address)
                print(description)
                print(rating)
                print()
                print('='*50)
                print(counter)
                print()
            except:
                description = {}
                description['name'] = name
                description['url'] = url
                missing.append(description)

#         if (counter + 1) % 1 == 0:
#             print(f"Attempted to collect {counter} hotel descriptions at {datetime.now()}.")
        counter += 1
    missing_df = pd.DataFrame(missing)
    descriptions_df = pd.DataFrame(descriptions)
    ratings_df = pd.DataFrame(ratings)
    addresses_df = pd.DataFrame(addresses)
#     geotags_df = pd.DataFrame(geotags)
    hotels_df = descriptions_df.merge(addresses_df, on='name')
    hotels_df = hotels_df.merge(ratings_df, on='name')
    hotels_df = hotels_df.drop_duplicates()
    return hotels_df, missing_df

# %%
# %%time

hotels_df, missing_df = get_hotels(dataframe)
# Out:
# ['900 Wilshire Boulevard : Los Angeles', ' California ', '90017', ' United States']
# {'name': 'InterContinental Hotels Los Angeles Downtown', 'description': '\nRevel in glamour and exhilaration that defines what it means to live the InterContinental life at the InterContinental Los Angeles Downtown. Excite in breathtaking views from the 70th-floor sky lobby and indulge in globally-inspired cuisine at our cutting-edge restaurants. Host your next event at our beautifully customizable meeting spaces with sweeping views of Los Angeles.\n'}
# {'name': 'InterContinental Hotels Los Angeles Downtown', 'rating': 'N/A'}
#
# ==================================================
# 290
#
# ['888 Howard Street : San Francisco', ' California ', '94103', ' United States']
# {'name': 'InterContinental Hotels San Francisco', 'description': "\nImmerse yourself in the  heart of the city at The InterContinental® San Francisco hotel. Our prime location in the heart of San Francisco, near Moscone Center and Union Square, allows you to explore the city's culture and charm while enjoying elegantly appointed rooms and luxurious amenities. Host your next event in our beautifully customizable meeting rooms and ballroom, while an elevated dining experience awaits you at our Michelin-starred  Luce restaurant and Bar 888 Grappa and Wine Bar.\n"}
# {'name': 'InterContinental Hotels San Francisco', 'rating': 'N/A'}
#
# ==================================================
# 360
#
# ['999 California Street : San Francisco', ' California ', '94108', ' United States']
# {'name': 'InterContinental Hotels Mark Hopkins San Francisco', 'description': "\nDiscover San Francisco's historic charm at the InterContinental® Mark Hopkins San Francisco hotel, where modern luxuries meet the Bay area's golden, glamorous era. Find breathtaking views at our Nob Hill hotel, featuring opulent rooms with unique artwork, modern amenities, and an easy stroll to the area's top attractions. Discover panoramic views of the City while enjoying signature cocktails at Top of the Mark sky lounge, or let our Concierge Desk curate your personalized, unforgettable stay.\n"}
# {'name': 'InterContinental Hotels Mark Hopkins San Francisco', 'rating': 'N/A'}
#
# ==================================================
# 363
#
# ['2151 Avenue Of The Stars : Los Angeles', ' California ', '90067', ' United States']
# {'name': 'InterContinental Hotels Los Angeles Century City', 'description': '\nEnjoy unrivaled hospitality at the InterContinental Los Angeles Century City at Beverly Hills. Minutes away from world-class shopping, major entertainment studios and sunny beaches of Southern California, our hotel features well-appointed guestrooms with stunning views and modern amenities. An elevated dining experience inspired by the cultural diversity of Los Angeles awaits you at Mari Los Angeles, while customizable meeting spaces provide the perfect place to host your next signature event.\n'}
# {'name': 'InterContinental Hotels Los Angeles Century City', 'rating': 'N/A'}
#
# ==================================================
# 390
#
# ['901 Bayfront Court : San Diego', ' California ', '92101', ' United States']
# {'name': 'InterContinental Hotels San Diego', 'description': '\nExuding the liveliness of the city with a soothing embrace of the Bay, the InterContinental San Diego is your exquisite urban retreat. Showcasing breathtaking views of the San Diego Bay, our downtown waterfront hotel features well-appointed rooms, refined amenities, and warm Californian hospitality. Discover coastal Southern California cuisine at Vistal Bar + Restaurant, unwind with an aero-inspired cocktail at Layover outdoor bar, or let us curate your stay in the heart of San Diego.\n'}
# {'name': 'InterContinental Hotels San Diego', 'rating': 'N/A'}
#
# ==================================================
# 452
#
# ['750 Cannery Row : Monterey', ' California ', '93940', ' United States']
# {'name': 'InterContinental Hotels The Clement Monterey', 'description': '\nPanoramic ocean views and coastal charm await you at the InterContinental® The Clement Monterey hotel. Overlooking the sapphire waters of Monterey Bay on Cannery Row, our waterfront hotel, resort and spa is where beauty and luxury indulge your senses. Treat yourself to a rejuvenating spa, or enjoy a soothing waterfront dining experience discovering Californian coastal classics. Host your next signature event at our customizable event space, overlooking the picturesque waters of Monterey Bay.\n'}
# {'name': 'InterContinental Hotels The Clement Monterey', 'rating': 'N/A'}
#
# ==================================================
# 498
#
# ['1401 Pennsylvania Ave Nw : Washington', ' District of Columbia ', '20004', ' United States']
# {'name': 'InterContinental Hotels The Willard Washington D.C.', 'description': "\nLocated in the heart of Washington, D.C., the Willard InterContinental is one of the most iconic hotel's in the nation’s capital. Nicknamed the “Residence of Presidents,” this legendary property has welcomed U.S. presidents, foreign dignitaries and celebrities, as well as been the site of many historic moments in history for over 200 years.  Centrally located, The Willard is two blocks from The White House and within walking distance to the monuments, memorials and museums on the National Mall.\n"}
# {'name': 'InterContinental Hotels The Willard Washington D.C.', 'rating': 'N/A'}
#
# ==================================================
# 698
#
# ['801 Wharf Street SW : Washington', ' District of Columbia ', '20024', ' United States']
# {'name': 'InterContinental Hotels Washington D.C. - The Wharf', 'description': "\nDiscover the nation's capital at the InterContinental® Washington D.C. - The Wharf. Nestled along the historic Washington Channel and in the heart of the lively D.C.  Wharf District, our luxury hotel offers a unique blend of contemporary style and sustainable design, featuring well-appointed guestrooms, residentially-inspired suites and plush amenities.  An elevated dining experience awaits you, while customizable meeting spaces provide inspiring waterfront views with naturally lit event spaces.\n"}
# {'name': 'InterContinental Hotels Washington D.C. - The Wharf', 'rating': 'N/A'}
#
# ==================================================
# 701
#
# ['100 Chopin Plaza : Miami', ' Florida ', '33131', ' United States']
# {'name': 'InterContinental Hotels Miami', 'description': '\nDiscover a new dimension of worldly travels paired with unrivaled hospitality at InterContinental Miami. Set in the heart of Miami, our hotel offers richly appointed accommodations with breathtaking views of Biscayne Bay. From dramatic digital artscapes, 653 luxury guestrooms & suites, we specialize in stylish flair, sophistication and world-class service. Relax at mySpa, enjoy a cocktail at Toro Toro and experience all that our hotel has to offer.\n'}
# {'name': 'InterContinental Hotels Miami', 'rating': 'N/A'}
#
# ==================================================
# 933
#
# ['2505 North West 87th Avenue : Doral', ' Florida ', '33172-1610', ' United States']
# {'name': 'InterContinental Hotels At Doral Miami', 'description': "\nDiscover a new dimension of worldly travels paired with unrivaled hospitality at InterContinental Doral Miami. Our hotel provides modern comforts of well-appointed rooms and plush amenities, alongside easy access to nearby attractions in the area including the International Mall, Dolphin Mall, City Place, and Downtown Doral. Discover Florida's international culinary heritage at our vibrant culinary concept, Blue Matisse, or enjoy handcrafted drinks and boutique spirits at Nau Lounge.\n"}
# {'name': 'InterContinental Hotels At Doral Miami', 'rating': 'N/A'}
#
# ==================================================
# 941
#
# ['3315 Peachtree Rd. Ne : Atlanta', ' Georgia ', '30326', ' United States']
# {'name': 'InterContinental Hotels Buckhead Atlanta', 'description': "\nRevel in unmatched hospitality and contemporary luxuries at the InterContinental® Buckhead Atlanta. Experience authentic Southern hospitality in our unique event spaces, which includes two opulent ballrooms and the breathtaking Windsor Garden. Reconnect with a range of holistic therapies and treatments from around the world at Jurlique Spa. Let award-winning chef Art Smith astonish you at the hotel's exquisite Southern Art restaurant, followed by a nightcap of fine whiskey at Bourbon Bar.\n"}
# {'name': 'InterContinental Hotels Buckhead Atlanta', 'rating': 'N/A'}
#
# ==================================================
# 1037
# ['505 North Michigan Ave : Chicago', ' Illinois ', '60611', ' United States']
# {'name': 'InterContinental Hotels Chicago Magnificent Mile', 'description': "\nStep into our airy lobby with a sweeping staircase and marble mosaic floors, and find yourself drifting into the Roaring Twenties at the InterContinental Chicago hotel, where historic origins blend into the modern luxuries of hospitality. Enjoy breathtaking views of Chicago from the 32nd-floor Tower Lounge, or unwind with a sauna or massage in our luxurious spa. An elevated dining experience with flawless service and gourmet cuisine typify Michael Jordan's Steak House and ENO Wine Bar.\n"}
# {'name': 'InterContinental Hotels Chicago Magnificent Mile', 'rating': 'N/A'}
#
# ==================================================
# 1263
#
# ['401 Ward Parkway : Kansas City', ' Missouri ', '64112', ' United States']
# {'name': 'InterContinental Hotels Kansas City At The Plaza', 'description': "\nDiscover Kansas City's historic charm at InterContinental Kansas City at the Plaza, offering well-appointed guest rooms and luxurious amenities paired with unrivaled hospitality and attention to detail. Discover Midwestern flair at American Slang Modern Brasserie, or unwind over handcrafted cocktails at the seasonal pool deck. Situated in the heart of Country Club Plaza, our hotel features beautifully designed and customizable events spaces including a Rooftop Ballroom.\n"}
# {'name': 'InterContinental Hotels Kansas City At The Plaza', 'rating': 'N/A'}
#
# ==================================================
# 1610
#
# ['444 St Charles Ave : New Orleans', ' Louisiana ', '70130', ' United States']
# {'name': 'InterContinental Hotels New Orleans', 'description': "\nDiscover New Orleans at the InterContinental® New Orleans hotel, where modern luxuries meet the city's historic charm. Luxurious rooms, plush amenities and breathtaking views at our rooftop pool await you. Indulge in masterfully crafted contemporary Cajun-Creole dishes at Trennase restaurant, or let our Concierge Desk curate your personalized, unforgettable stay.\n"}
# {'name': 'InterContinental Hotels New Orleans', 'rating': 'N/A'}
#
# ==================================================
# 1748
#
# ['510 Atlantic Avenue : Boston', ' Massachusetts ', '02210', ' United States']
# {'name': 'InterContinental Hotels Boston', 'description': "\nWith a striking backdrop of Fort Point Channel, immerse yourself in Boston's history at the InterContinental® Boston hotel, where well-appointed rooms and fine amenities complement your cultural explorations. Savor signature cocktails at our lively RumBa bar, or drift into France's Côte d'Azur region at our acclaimed Miel Brasserie. For your next signature event, our polished and customizable event spaces with state-of-the-art technology allow you to host an unforgettable event with ease.\n"}
# {'name': 'InterContinental Hotels Boston', 'rating': 'N/A'}
#
# ==================================================
# 1873
#
# ['5005 Glumack Drive : Minneapolis', ' Minnesota ', '55450', ' United States']
# {'name': 'InterContinental Hotels Minneapolis - St. Paul Airport', 'description': '\nExperience the spirit of Minnesota matched with unrivaled hospitality at the InterContinental Minneapolis - St. Paul Airport. Directly connected to the airport, our hotel offers distinguishing conveniences and amenities that magnify your stay with us. Dine in our acclaimed restaurants, or host an event in our customizable meeting spaces. Our hotel is located only 20 minutes to the downtowns of Minneapolis or St. Paul, and 5 minutes to Mall of America.\n'}
# {'name': 'InterContinental Hotels Minneapolis - St. Paul Airport', 'rating': 'N/A'}
#
# ==================================================
# 2061
#
# ['11 East Kellogg Boulevard : St. Paul', ' Minnesota ', '55101', ' United States']
# {'name': 'InterContinental Hotels Saint Paul Riverfront', 'description': '\nFind yourself atop the bluffs of the Mississippi River at the InterContinental Saint Paul Riverfront hotel  in the heart of downtown. Steps away from live theater, renowned museums, and world-class dining and shopping experiences, our hotel features well-appointed rooms and refined amenities that complement the  breathtaking riverfront views. An elevated dining experience awaits you at Citizen, while our beautifully customizable event spaces allow you to host your next signature event with ease.\n'}
# {'name': 'InterContinental Hotels Saint Paul Riverfront', 'rating': 'N/A'}
#
# ==================================================
# 2072
#
# ['3355 Las Vegas Boulevard South : Las Vegas', ' Nevada ', '89109', ' United States']
# {'name': 'InterContinental - Alliance Resorts The Venetian Resort', 'description': '\nLocated in the heart of the Las Vegas Strip, The Venetian Resort Las Vegas features all-suite accommodations, exquisite restaurants, celebrity chefs, world-class entertainment, nightlife, and shopping. The resort also offers Canyon Ranch® spa + fitness, a five-acre pool and garden deck, The Aquatic Club, TAO Nightclub, Grand Canal Shoppes®, Prestige at The Palazzo®, and a 120,000-square-foot casino and poker room complete the all-encompassing resort experience.\n'}
# {'name': 'InterContinental - Alliance Resorts The Venetian Resort', 'rating': 'N/A'}
#
# ==================================================
# 2258
#
# ['3325 Las Vegas Blvd. South : Las Vegas', ' Nevada ', '89109', ' United States']
# {'name': 'InterContinental - Alliance Resorts Palazzo at The Venetian Resort', 'description': '\nRefinement doesn’t mean having less, it means having more of the things you want. The Palazzo tower at The Venetian Resort is classic Italian luxury, refined for your modern tastes. All suites, all newly redesigned. Unique culinary and cocktail destinations, including the inventive Electra Cocktail Club and romantic Rosina. Every experience created to shake up your soul and your martini. We invite you to open your mind to what luxury can mean.\n'}
# {'name': 'InterContinental - Alliance Resorts Palazzo at The Venetian Resort', 'rating': 'N/A'}
#
# ==================================================
# 2259
#
# ['300 West 44th Street : New York', ' New York ', '10036', ' United States']
# {'name': 'InterContinental Hotels New York Times Square', 'description': "\nEscape the bustle of New York's streets in the tranquil surroundings of the InterContinental® New York Times Square hotel, where tree-inspired columns and lush decor connect you to the natural beauty and energy of New York City. Savor signature cocktails in The Stinger Cocktail Bar and Kitchen before exploring the city’s dining, shopping and theater scenes. Host your next refined event with ease in our beautifully customizable meeting spaces with our dedicated team assuring every detail.\n"}
# {'name': 'InterContinental Hotels New York Times Square', 'rating': 'N/A'}
#
# ==================================================
# 2317
#
# ['111 East 48th St : New York', ' New York ', '10017-1297', ' United States']
# {'name': 'InterContinental Hotels New York Barclay', 'description': "\nRelish revisiting the Roaring Twenties amidst modern Manhattan's glamor at the InterContinental New York Barclay. Preserving its rich history through signature Federalist style décor, our hotel continues to evolve to bring you modern luxuries of hospitality while maintaining its residential feel. Savor masterfully handcrafted cocktails while enjoying live jazz at The Parlour, or host your next refined event at our beautifully customizable meeting spaces and ballrooms.\n"}
# {'name': 'InterContinental Hotels New York Barclay', 'rating': 'N/A'}
#
# ==================================================
# 2324
#
# ['9801 Carnegie Avenue : Cleveland', ' Ohio ', '44106', ' United States']
# {'name': 'InterContinental Hotels Cleveland', 'description': '\nEnjoy modern comforts and well-appointed rooms alongside exploring Cleveland at InterContinental® Cleveland. Conveniently located adjacent to Cleveland Clinic Main Campus, our hotel provides easy access to University Circle, Cleveland Museum of Art, and other top attractions in the area. An elevated dining experience featuring contemporary world cuisine awaits you at Table 45 Restaurant, while customizable meeting spaces provide the perfect place to host your next refined event.\n'}
# {'name': 'InterContinental Hotels Cleveland', 'rating': 'N/A'}
#
# ==================================================
# 2671
# ['8800 Euclid Avenue : Cleveland', ' Ohio ', '44106', ' United States']
# {'name': 'InterContinental Hotels Suites Hotel Cleveland', 'description': "\nAn oasis for relaxation, rejuvenation, and improvements to holistic well-being, InterContinental® Suites Hotel Cleveland is proud to be the region's only wellness focused all-suite hotel. Our hotel is conveniently close to Cleveland Clinic Main Campus, while also providing easy access to the Cleveland's top attractions such as Cleveland Museum of Art, Rock & Roll Hall of Fame, and East 4th, along with Case Western Reserve University and Cleveland State University.\n"}
# {'name': 'InterContinental Hotels Suites Hotel Cleveland', 'rating': 'N/A'}
#
# ==================================================
# 2672
#
# ['6750 Main Street : Houston', ' Texas ', '77030', ' United States']
# {'name': 'InterContinental Hotels Houston - Medical Center', 'description': "\nRevel in modern design paired with unrivaled hospitality in the heart of the Texas Medical Center at the InterContinental Houston - Medical Center. Adjacent to the world’s largest medical center, our hotel provides easy access to the city's top attractions with METRORail, which is within walking distance of the property. Discover Houston's fine dining, renowned international arts, and famous Museum District. If rest and relaxation is your aim, take comfort in the hotel’s spacious luxury suite.\n"}
# {'name': 'InterContinental Hotels Houston - Medical Center', 'rating': 'N/A'}
#
# ==================================================
# 3301
#
# ['701 Congress Avenue : Austin', ' Texas ', '78701', ' United States']
# {'name': 'InterContinental Hotels Stephen F. Austin', 'description': "\nImmerse yourself in Austin's history at the InterContinental® Stephen F. Austin. A landmark hotel in Austin featuring the historic Art Deco façade and opulent décor, our hotel combines authentic Texan hospitality with elegantly appointed rooms and plush amenities. Drift into the prohibition era with an vintage cocktail at the Stephen F's Bar, host your next signature event at our beautifully customizable meeting spaces, or let our Concierge Desk curate your personalized, unforgettable stay.\n"}
# {'name': 'InterContinental Hotels Stephen F. Austin', 'rating': 'N/A'}
#
# ==================================================
# 3361
#
# CPU times: user 4.67 s, sys: 121 ms, total: 4.79 s
# Wall time: 11.4 s

# %%
hotels_df.to_csv('ihg_hotels_descriptions6.csv')

# %%
missing_df.to_csv('missing_ihg_hotels4.csv')

# %%
hotels_df
# Out:
#                                                  name  \
# 0        InterContinental Hotels Los Angeles Downtown
# 1               InterContinental Hotels San Francisco
# 2   InterContinental Hotels Mark Hopkins San Franc...
# 3    InterContinental Hotels Los Angeles Century City
# 4                   InterContinental Hotels San Diego
# 5        InterContinental Hotels The Clement Monterey
# 6   InterContinental Hotels The Willard Washington...
# 7   InterContinental Hotels Washington D.C. - The ...
# 8                       InterContinental Hotels Miami
# 9              InterContinental Hotels At Doral Miami
# 10           InterContinental Hotels Buckhead Atlanta
# 11   InterContinental Hotels Chicago Magnificent Mile
# 12   InterContinental Hotels Kansas City At The Plaza
# 13                InterContinental Hotels New Orleans
# 14                     InterContinental Hotels Boston
# 15  InterContinental Hotels Minneapolis - St. Paul...
# 16      InterContinental Hotels Saint Paul Riverfront
# 17  InterContinental - Alliance Resorts The Veneti...
# 18  InterContinental - Alliance Resorts Palazzo at...
# 19      InterContinental Hotels New York Times Square
# 20           InterContinental Hotels New York Barclay
# 21                  InterContinental Hotels Cleveland
# 22     InterContinental Hotels Suites Hotel Cleveland
# 23   InterContinental Hotels Houston - Medical Center
# 24          InterContinental Hotels Stephen F. Austin
#
#                                           description  \
# 0   \nRevel in glamour and exhilaration that defin...
# 1   \nImmerse yourself in the  heart of the city a...
# 2   \nDiscover San Francisco's historic charm at t...
# 3   \nEnjoy unrivaled hospitality at the InterCont...
# 4   \nExuding the liveliness of the city with a so...
# 5   \nPanoramic ocean views and coastal charm awai...
# 6   \nLocated in the heart of Washington, D.C., th...
# 7   \nDiscover the nation's capital at the InterCo...
# 8   \nDiscover a new dimension of worldly travels ...
# 9   \nDiscover a new dimension of worldly travels ...
# 10  \nRevel in unmatched hospitality and contempor...
# 11  \nStep into our airy lobby with a sweeping sta...
# 12  \nDiscover Kansas City's historic charm at Int...
# 13  \nDiscover New Orleans at the InterContinental...
# 14  \nWith a striking backdrop of Fort Point Chann...
# 15  \nExperience the spirit of Minnesota matched w...
# 16  \nFind yourself atop the bluffs of the Mississ...
# 17  \nLocated in the heart of the Las Vegas Strip,...
# 18  \nRefinement doesn’t mean having less, it mean...
# 19  \nEscape the bustle of New York's streets in t...
# 20  \nRelish revisiting the Roaring Twenties amids...
# 21  \nEnjoy modern comforts and well-appointed roo...
# 22  \nAn oasis for relaxation, rejuvenation, and i...
# 23  \nRevel in modern design paired with unrivaled...
# 24  \nImmerse yourself in Austin's history at the ...
#
#                                                   url  \
# 0   https://www.ihg.com/intercontinental/hotels/us...
# 1   https://www.ihg.com/intercontinental/hotels/us...
# 2   https://www.ihg.com/intercontinental/hotels/us...
