# %%
import numpy as np
import pandas as pd

# pd.set_option('max_columns', None)
# pd.set_option('max_rows', None)\n",

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

import en_core_web_lg
from spacy.lang.en import English
from spacy.lang.en.stop_words import STOP_WORDS

from textblob import TextBlob

from datetime import datetime

# %%
data = pd.read_csv('all_hotels_cleaned.csv')

# %%
data.head()
# Out:
#    Unnamed: 0 rewards              brand                              name  \
# 0           0  Hilton        Hampton Inn        Hampton Inn Alexander City
# 1           1  Hilton        Hampton Inn              Hampton Inn Wetumpka
# 2           2  Hilton        Hampton Inn                Hampton Inn Auburn
# 3           3  Hilton                Tru              Tru by Hilton Auburn
# 4           4  Hilton  Hilton Garden Inn  Hilton Garden Inn Auburn/Opelika
#
#   rating                                        description  \
# 0    4.0  We’re right off Highway 280, 25 minutes away f...
# 1    5.0  We’re on the banks of the Coosa River, a short...
# 2    4.0  We're off I-85, under 10 minutes from Chewacla...
# 3    4.0  Make this Tru by Hilton your own. We’ll help, ...
# 4    4.0  Our hotel is just off I-85, minutes away from ...
#
#                      street            city state postal  \
# 0     1551 Elkahatchee Road  Alexander City    AL  35010
# 1     350 South Main Street        Wetumpka    AL  36092
# 2       2430 S. College St.          Auburn    AL  36832
# 3          2411 W Pace Blvd          Auburn    AL  36830
# 4  2555 Hilton Garden Drive          Auburn    AL  36830
#
#                                                  url  class_id  \
# 0  https://hamptoninn3.hilton.com/en/hotels/alaba...         4
# 1  https://hamptoninn3.hilton.com/en/hotels/alaba...         4
# 2  https://hamptoninn3.hilton.com/en/hotels/alaba...         4
# 3  https://tru3.hilton.com/en/hotels/alabama/tru-...         5
# 4  https://hiltongardeninn3.hilton.com/en/hotels/...         3
#
#                     category
# 0  Limited-Service Mid-Scale
# 1  Limited-Service Mid-Scale
# 2  Limited-Service Mid-Scale
# 3                     Budget
# 4         Full-Service Entry

# %%
bagofwords = []
columns = ['rewards', 'brand', 'description', 'city', 'category']
for index, row in data.iterrows():
    words = ''
    for col in columns:
        words += ''.join(row[col]) + ' '
    bagofwords.append(words)

data['Bag_of_words'] = bagofwords

# %%
nlp = en_core_web_lg.load()

# %%
data.head(5)
# Out:
#    Unnamed: 0 rewards              brand                              name  \
# 0           0  Hilton        Hampton Inn        Hampton Inn Alexander City
# 1           1  Hilton        Hampton Inn              Hampton Inn Wetumpka
# 2           2  Hilton        Hampton Inn                Hampton Inn Auburn
# 3           3  Hilton                Tru              Tru by Hilton Auburn
# 4           4  Hilton  Hilton Garden Inn  Hilton Garden Inn Auburn/Opelika
#
#   rating                                        description  \
# 0    4.0  We’re right off Highway 280, 25 minutes away f...
# 1    5.0  We’re on the banks of the Coosa River, a short...
# 2    4.0  We're off I-85, under 10 minutes from Chewacla...
# 3    4.0  Make this Tru by Hilton your own. We’ll help, ...
# 4    4.0  Our hotel is just off I-85, minutes away from ...
#
#                      street            city state postal  \
# 0     1551 Elkahatchee Road  Alexander City    AL  35010
# 1     350 South Main Street        Wetumpka    AL  36092
# 2       2430 S. College St.          Auburn    AL  36832
# 3          2411 W Pace Blvd          Auburn    AL  36830
# 4  2555 Hilton Garden Drive          Auburn    AL  36830
#
#                                                  url  class_id  \
# 0  https://hamptoninn3.hilton.com/en/hotels/alaba...         4
# 1  https://hamptoninn3.hilton.com/en/hotels/alaba...         4
# 2  https://hamptoninn3.hilton.com/en/hotels/alaba...         4
# 3  https://tru3.hilton.com/en/hotels/alabama/tru-...         5
# 4  https://hiltongardeninn3.hilton.com/en/hotels/...         3
#
#                     category  \
# 0  Limited-Service Mid-Scale
# 1  Limited-Service Mid-Scale
# 2  Limited-Service Mid-Scale
# 3                     Budget
# 4         Full-Service Entry
#
#                                         Bag_of_words
# 0  Hilton Hampton Inn We’re right off Highway 280...
# 1  Hilton Hampton Inn We’re on the banks of the C...
# 2  Hilton Hampton Inn We're off I-85, under 10 mi...
# 3  Hilton Tru Make this Tru by Hilton your own. W...
# 4  Hilton Hilton Garden Inn Our hotel is just off...

# %%
# Creating spacydocs for each bag of words for each hotel
spacydocs = []
for x in data['Bag_of_words']:
    doc = nlp(x)
    spacydocs.append(doc)

data['spacydocs'] = spacydocs

# %%
data.head()
# Out:
#    Unnamed: 0 rewards              brand                              name  \
# 0           0  Hilton        Hampton Inn        Hampton Inn Alexander City
# 1           1  Hilton        Hampton Inn              Hampton Inn Wetumpka
# 2           2  Hilton        Hampton Inn                Hampton Inn Auburn
# 3           3  Hilton                Tru              Tru by Hilton Auburn
# 4           4  Hilton  Hilton Garden Inn  Hilton Garden Inn Auburn/Opelika
#
#   rating                                        description  \
# 0    4.0  We’re right off Highway 280, 25 minutes away f...
# 1    5.0  We’re on the banks of the Coosa River, a short...
# 2    4.0  We're off I-85, under 10 minutes from Chewacla...
# 3    4.0  Make this Tru by Hilton your own. We’ll help, ...
# 4    4.0  Our hotel is just off I-85, minutes away from ...
#
#                      street            city state postal  \
# 0     1551 Elkahatchee Road  Alexander City    AL  35010
# 1     350 South Main Street        Wetumpka    AL  36092
# 2       2430 S. College St.          Auburn    AL  36832
# 3          2411 W Pace Blvd          Auburn    AL  36830
# 4  2555 Hilton Garden Drive          Auburn    AL  36830
#
#                                                  url  class_id  \
# 0  https://hamptoninn3.hilton.com/en/hotels/alaba...         4
# 1  https://hamptoninn3.hilton.com/en/hotels/alaba...         4
# 2  https://hamptoninn3.hilton.com/en/hotels/alaba...         4
# 3  https://tru3.hilton.com/en/hotels/alabama/tru-...         5
# 4  https://hiltongardeninn3.hilton.com/en/hotels/...         3
#
#                     category  \
# 0  Limited-Service Mid-Scale
# 1  Limited-Service Mid-Scale
# 2  Limited-Service Mid-Scale
# 3                     Budget
# 4         Full-Service Entry
#
#                                         Bag_of_words  \
# 0  Hilton Hampton Inn We’re right off Highway 280...
# 1  Hilton Hampton Inn We’re on the banks of the C...
# 2  Hilton Hampton Inn We're off I-85, under 10 mi...
# 3  Hilton Tru Make this Tru by Hilton your own. W...
# 4  Hilton Hilton Garden Inn Our hotel is just off...
#
#                                            spacydocs
# 0  (Hilton, Hampton, Inn, We, ’re, right, off, Hi...
# 1  (Hilton, Hampton, Inn, We, ’re, on, the, banks...
# 2  (Hilton, Hampton, Inn, We, 're, off, I-85, ,, ...
# 3  (Hilton, Tru, Make, this, Tru, by, Hilton, you...
# 4  (Hilton, Hilton, Garden, Inn, Our, hotel, is, ...

# %%
# Creating vectors for the bag of words for each hotel
vectorlist = []
for doc in data['spacydocs']:
    vector = doc.vector
    vectorlist.append(vector)
data['vectors'] = vectorlist

# %%
data.shape
# Out:
# (21248, 16)

# %%
data.to_csv('data_for_app6.csv')

# %%
# data = pd.read_csv('data_for_app5.csv', delimiter='\t')

# %%
# creating a full address column to use for getting geolocations
addresses = []
for index, row in data.iterrows():
    street = row['street']
    city = row['city']
    state = row['state']
    postal = row['postal']
    address = street +', ' + city + ', ' + state+ ' ' + postal
    addresses.append(address)
data['address'] = addresses

# %%
addresses2 = []
for index, row in data.iterrows():
    city = row['city']
    state = row['state']
    postal = row['postal']
    address = city + ', ' + state+ ' ' + postal
    addresses2.append(address)
data['address2'] = addresses2

# %%
data.head()
# Out:
#    Unnamed: 0 rewards              brand                              name  \
# 0           0  Hilton        Hampton Inn        Hampton Inn Alexander City
# 1           1  Hilton        Hampton Inn              Hampton Inn Wetumpka
# 2           2  Hilton        Hampton Inn                Hampton Inn Auburn
# 3           3  Hilton                Tru              Tru by Hilton Auburn
# 4           4  Hilton  Hilton Garden Inn  Hilton Garden Inn Auburn/Opelika
#
#   rating                                        description  \
# 0    4.0  We’re right off Highway 280, 25 minutes away f...
# 1    5.0  We’re on the banks of the Coosa River, a short...
# 2    4.0  We're off I-85, under 10 minutes from Chewacla...
# 3    4.0  Make this Tru by Hilton your own. We’ll help, ...
# 4    4.0  Our hotel is just off I-85, minutes away from ...
#
#                      street            city state postal  \
# 0     1551 Elkahatchee Road  Alexander City    AL  35010
# 1     350 South Main Street        Wetumpka    AL  36092
# 2       2430 S. College St.          Auburn    AL  36832
# 3          2411 W Pace Blvd          Auburn    AL  36830
# 4  2555 Hilton Garden Drive          Auburn    AL  36830
#
#                                                  url  class_id  \
# 0  https://hamptoninn3.hilton.com/en/hotels/alaba...         4
# 1  https://hamptoninn3.hilton.com/en/hotels/alaba...         4
# 2  https://hamptoninn3.hilton.com/en/hotels/alaba...         4
# 3  https://tru3.hilton.com/en/hotels/alabama/tru-...         5
# 4  https://hiltongardeninn3.hilton.com/en/hotels/...         3
#
#                     category  \
# 0  Limited-Service Mid-Scale
# 1  Limited-Service Mid-Scale
# 2  Limited-Service Mid-Scale
# 3                     Budget
# 4         Full-Service Entry
#
#                                         Bag_of_words  \
# 0  Hilton Hampton Inn We’re right off Highway 280...
# 1  Hilton Hampton Inn We’re on the banks of the C...
# 2  Hilton Hampton Inn We're off I-85, under 10 mi...
# 3  Hilton Tru Make this Tru by Hilton your own. W...
# 4  Hilton Hilton Garden Inn Our hotel is just off...
#
#                                            spacydocs  \
# 0  (Hilton, Hampton, Inn, We, ’re, right, off, Hi...
# 1  (Hilton, Hampton, Inn, We, ’re, on, the, banks...
# 2  (Hilton, Hampton, Inn, We, 're, off, I-85, ,, ...
# 3  (Hilton, Tru, Make, this, Tru, by, Hilton, you...
# 4  (Hilton, Hilton, Garden, Inn, Our, hotel, is, ...
#
#                                              vectors  \
# 0  [0.110708795, 0.18874672, -0.016256696, -0.054...
# 1  [0.022146616, 0.18830003, -0.057727393, -0.104...
# 2  [0.032046665, 0.18124907, 0.040364493, -0.0403...
# 3  [0.025436003, 0.105327815, -0.09880912, -0.104...
# 4  [0.12775657, 0.13718104, -0.0058974824, -0.131...
#
#                                            address                  address2
# 0  1551 Elkahatchee Road, Alexander City, AL 35010  Alexander City, AL 35010
# 1        350 South Main Street, Wetumpka, AL 36092        Wetumpka, AL 36092
# 2            2430 S. College St., Auburn, AL 36832          Auburn, AL 36832
# 3               2411 W Pace Blvd, Auburn, AL 36830          Auburn, AL 36830
# 4       2555 Hilton Garden Drive, Auburn, AL 36830          Auburn, AL 36830

# %%
dataclean = data.drop(columns=['Unnamed: 0', 'street', 'brand', 'city', 'postal', 'Bag_of_words', 'spacydocs', 'description'])

# %%
dataclean.to_csv('data_for_app6_slim.csv')

# %%
dataclean.head()
# Out:
#   rewards                              name rating  \
# 0  Hilton        Hampton Inn Alexander City    4.0
# 1  Hilton              Hampton Inn Wetumpka    5.0
# 2  Hilton                Hampton Inn Auburn    4.0
# 3  Hilton              Tru by Hilton Auburn    4.0
# 4  Hilton  Hilton Garden Inn Auburn/Opelika    4.0
#
#                                                  url  class_id  \
# 0  https://hamptoninn3.hilton.com/en/hotels/alaba...         4
# 1  https://hamptoninn3.hilton.com/en/hotels/alaba...         4
# 2  https://hamptoninn3.hilton.com/en/hotels/alaba...         4
# 3  https://tru3.hilton.com/en/hotels/alabama/tru-...         5
# 4  https://hiltongardeninn3.hilton.com/en/hotels/...         3
#
#                     category  \
# 0  Limited-Service Mid-Scale
# 1  Limited-Service Mid-Scale
# 2  Limited-Service Mid-Scale
# 3                     Budget
# 4         Full-Service Entry
#
#                                              vectors  \
# 0  [0.110708795, 0.18874672, -0.016256696, -0.054...
# 1  [0.022146616, 0.18830003, -0.057727393, -0.104...
# 2  [0.032046665, 0.18124907, 0.040364493, -0.0403...
# 3  [0.025436003, 0.105327815, -0.09880912, -0.104...
# 4  [0.12775657, 0.13718104, -0.0058974824, -0.131...
#
#                                            address                  address2
# 0  1551 Elkahatchee Road, Alexander City, AL 35010  Alexander City, AL 35010
# 1        350 South Main Street, Wetumpka, AL 36092        Wetumpka, AL 36092
# 2            2430 S. College St., Auburn, AL 36832          Auburn, AL 36832
# 3               2411 W Pace Blvd, Auburn, AL 36830          Auburn, AL 36830
# 4       2555 Hilton Garden Drive, Auburn, AL 36830          Auburn, AL 36830

# %%
data['category'].unique()
# Out:
# array(['Limited-Service Mid-Scale', 'Budget', 'Full-Service Entry',
#        'Extended-Stay, All-Suite', 'Full-Service Mid-Scale',
#        'Lifestyle, Boutique', 'Full-Service Upper-Scale',
#        'Vacation Club, Condos, Villas', 'Luxury'], dtype=object)

# %%
catreplace = {'Limited-Service Mid-Scale' : 8, 'Budget' : 9, 'Full-Service Entry' : 6,
       'Extended-Stay, All-Suite' : 7, 'Full-Service Mid-Scale' : 5,
       'Lifestyle, Boutique' : 3, 'Full-Service Upper-Scale' : 4,
       'Vacation Club, Condos, Villas' : 2, 'Luxury' : 1}

# %%
dataclean['category'] = dataclean['category'].replace(catreplace)

# %%
dataclean.to_csv('data_for_app6_slim.csv')

# %%
vectormeanlist = []
for x in dataclean['vectors']:
    x = x.mean()
    vectormeanlist.append(x)
dataclean['vectormean'] = vectormeanlist

# %%
dataclean = dataclean.drop(columns=['vectors', 'class_id'])

# %%
dataclean.to_csv('data_for_app6_slim.csv')
