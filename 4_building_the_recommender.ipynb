# %%
import pandas as pd
import numpy as np

import en_core_web_lg
from spacy.lang.en import English
# from spacy.lang.en.stop_words import STOP_WORDS
from sklearn.metrics.pairwise import cosine_similarity

# %%
data = pd.read_csv('data_for_app6.csv')

# %%
data = data.drop(columns=['Unnamed: 0'])
data.head()
# Out:
#    Unnamed: 0.1 rewards              brand                              name  \
# 0             0  Hilton        Hampton Inn        Hampton Inn Alexander City
# 1             1  Hilton        Hampton Inn              Hampton Inn Wetumpka
# 2             2  Hilton        Hampton Inn                Hampton Inn Auburn
# 3             3  Hilton                Tru              Tru by Hilton Auburn
# 4             4  Hilton  Hilton Garden Inn  Hilton Garden Inn Auburn/Opelika
#
#   rating                                        description  \
# 0    4.0  We’re right off Highway 280, 25 minutes away f...
# 1    5.0  We’re on the banks of the Coosa River, a short...
# 2    4.0  We're off I-85, under 10 minutes from Chewacla...
# 3    4.0  Make this Tru by Hilton your own. We’ll help, ...
# 4    4.0  Our hotel is just off I-85, minutes away from ...
#
#                      street            city state postal  \
# 0     1551 Elkahatchee Road  Alexander City    AL  35010
# 1     350 South Main Street        Wetumpka    AL  36092
# 2       2430 S. College St.          Auburn    AL  36832
# 3          2411 W Pace Blvd          Auburn    AL  36830
# 4  2555 Hilton Garden Drive          Auburn    AL  36830
#
#                                                  url  class_id  \
# 0  https://hamptoninn3.hilton.com/en/hotels/alaba...         4
# 1  https://hamptoninn3.hilton.com/en/hotels/alaba...         4
# 2  https://hamptoninn3.hilton.com/en/hotels/alaba...         4
# 3  https://tru3.hilton.com/en/hotels/alabama/tru-...         5
# 4  https://hiltongardeninn3.hilton.com/en/hotels/...         3
#
#                     category  \
# 0  Limited-Service Mid-Scale
# 1  Limited-Service Mid-Scale
# 2  Limited-Service Mid-Scale
# 3                     Budget
# 4         Full-Service Entry
#
#                                         Bag_of_words  \
# 0  Hilton Hampton Inn We’re right off Highway 280...
# 1  Hilton Hampton Inn We’re on the banks of the C...
# 2  Hilton Hampton Inn We're off I-85, under 10 mi...
# 3  Hilton Tru Make this Tru by Hilton your own. W...
# 4  Hilton Hilton Garden Inn Our hotel is just off...
#
#                                            spacydocs  \
# 0  Hilton Hampton Inn We’re right off Highway 280...
# 1  Hilton Hampton Inn We’re on the banks of the C...
# 2  Hilton Hampton Inn We're off I-85, under 10 mi...
# 3  Hilton Tru Make this Tru by Hilton your own. W...
# 4  Hilton Hilton Garden Inn Our hotel is just off...
#
#                                              vectors  \
# 0  [ 1.10708795e-01  1.88746721e-01 -1.62566956e-...
# 1  [ 2.21466161e-02  1.88300028e-01 -5.77273928e-...
# 2  [ 3.20466645e-02  1.81249067e-01  4.03644927e-...
# 3  [ 2.54360028e-02  1.05327815e-01 -9.88091230e-...
# 4  [ 1.27756566e-01  1.37181044e-01 -5.89748239e-...
#
#                                            address                  address2  \
# 0  1551 Elkahatchee Road, Alexander City, AL 35010  Alexander City, AL 35010
# 1        350 South Main Street, Wetumpka, AL 36092        Wetumpka, AL 36092
# 2            2430 S. College St., Auburn, AL 36832          Auburn, AL 36832
# 3               2411 W Pace Blvd, Auburn, AL 36830          Auburn, AL 36830
# 4       2555 Hilton Garden Drive, Auburn, AL 36830          Auburn, AL 36830
#
#    vectormean
# 0    0.010736
# 1    0.005572
# 2    0.009107
# 3    0.005324
# 4    0.007964

# %%
for x in data['vectors'][:5]:
    print(x)
    print('='*50)

# %%
newarraylist = []
for x in data['vectors']:
    x = x.replace('[', '').replace(']','')
    x = x.split(' ')
    
    newarray = []
    for z in x:
        z = z.strip()
        if len(z) >2:
            newarray.append(float(z))
    newarray = np.array(newarray)
    newarraylist.append(newarray)
#     print(newarray)
#     print(type(newarray))
#     print()
#     print('='*50)
#     print()
data['vectors'] = newarraylist

# %%
def trim_state(input):
    return data[data['state']==input]

# %%
def trim_cat(input):
    catlist = input.split(',')
    catlist = [x.strip() for x in catlist]
    newdata= []
    for index, row in data.iterrows():
        category = row['category']
        category = category.split(' ')
        for x in category:
            x = x.replace(',','').strip()
            if x in catlist:
#                 print(row)
                newdata.append(row)
                print(x)
                print('='*50)
#         if x in catlist:
#             print(type(x))
#     data['new_category'] = data['category'].apply(lambda x: [i[0].strip()for i in x])
#     return data.head(5)
    newdatadf = pd.DataFrame(newdata)
    return newdatadf
#     return data

# %%
def trim_rating(input):
    data['rating'] = data['rating'].replace({'New Hotel' : 6})
    data['rating'] = [float(x) for x in data['rating']]
    data2 = data[(data['rating'] >= float(input))]
    return data2

# %%
state_input = input('Select your state ')
cat_input = input('Select your categories')
rate_input = input('Select your minimum rating')
# Out:
# Select your state MS
# Select your categoriesLimited-Service, Full-Service
# Select your minimum rating4

# %%
data = trim_state(state_input)

# %%
data = trim_cat(cat_input)
# Out:
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Full-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Full-Service
# ==================================================
# Full-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Full-Service
# ==================================================
# Limited-Service
# ==================================================
# Full-Service
# ==================================================
# Limited-Service
# ==================================================
# Full-Service
# ==================================================
# Full-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Full-Service
# ==================================================
# Limited-Service
# ==================================================
# Full-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Full-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Full-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Full-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Full-Service
# ==================================================
# Limited-Service
# ==================================================
# Full-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Full-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Full-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Full-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Full-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Full-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Full-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Full-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Full-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Full-Service
# ==================================================
# Limited-Service
# ==================================================
# Full-Service
# ==================================================
# Full-Service
# ==================================================
# Full-Service
# ==================================================
# Full-Service
# ==================================================
# Full-Service
# ==================================================
# Full-Service
# ==================================================
# Full-Service
# ==================================================
# Full-Service
# ==================================================
# Full-Service
# ==================================================
# Full-Service
# ==================================================
# Full-Service
# ==================================================
# Full-Service
# ==================================================
# Full-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Full-Service
# ==================================================
# Full-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================
# Limited-Service
# ==================================================

# %%
data = trim_rating(rate_input)

# %%
data
# Out:
#        Unnamed: 0.1  rewards        brand  \
# 2229           2229   Hilton  Hampton Inn
# 2230           2230   Hilton  Hampton Inn
# 2231           2231   Hilton   Doubletree
# 2232           2232   Hilton  Hampton Inn
# 2234           2234   Hilton  Hampton Inn
# ...             ...      ...          ...
# 18095         18121  Wyndham    La Quinta
# 18099         18125  Wyndham    La Quinta
# 18110         18136  Wyndham    La Quinta
# 18114         18140  Wyndham    La Quinta
# 18119         18145  Wyndham    La Quinta
#
#                                                     name  rating  \
# 2229                             Hampton Inn Oxford-West     4.5
# 2230                Hampton Inn Oxford/Conference Center     4.5
# 2231                   DoubleTree by Hilton Hotel Biloxi     4.0
# 2232                                  Hampton Inn Biloxi     4.5
# 2234             Hampton Inn & Suites D'Iberville Biloxi     5.0
# ...                                                  ...     ...
# 18095           La Quinta Inn & Suites by Wyndham Oxford     5.0
# 18099  La Quinta Inn & Suites by Wyndham Jackson Airport     4.0
# 18110  La Quinta Inn & Suites by Wyndham Starkville a...     4.5
# 18114           La Quinta Inn & Suites by Wyndham Tupelo     4.0
# 18119        La Quinta Inn & Suites by Wyndham Vicksburg     4.0
#
#                                              description  \
# 2229   You can feel the Ole Miss pride from our hotel...
# 2230   Our hotel is a three-minute walk from the Oxfo...
# 2231   Welcome to our beachfront hotel in Biloxi, whe...
# 2232   Get ready for Biloxi Beach days, adjacent to o...
# 2234   Off I-110, our hotel near the Gulf of Mexico i...
# ...                                                  ...
# 18095    A Bright Stay in Oxford   Pet-friendly hotel...
# 18099    The City with Soul   Pet-friendly hotel off ...
# 18110    A Bright Stay in Starkville   Colorful hotel...
# 18114    Southern Hospitality in Tupelo   Pleasant ho...
# 18119    Visit Vicksburg   Inviting hotel off US-80, ...
#
#                          street        city state postal  \
# 2229         110 Heritage Drive      Oxford    MS  38655
# 2230         103 Ed Perry Blvd.      Oxford    MS  38655
# 2231        940 Beach Boulevard      Biloxi    MS  39530
# 2232       1138 Beach Boulevard      Biloxi    MS  39530
# 2234     3828 Promenade Parkway  DIberville    MS  39540
# ...                         ...         ...   ...    ...
# 18095        1171 Frontage Road      Oxford    MS  38655
# 18099          501 S Pearson RD       Pearl    MS  39208
# 18110           982 Hwy 12 East  Starkville    MS  39759
# 18114        1013 N Gloster St.      Tupelo    MS  38804
# 18119  4160 South Frontage Road   Vicksburg    MS  39180
#
#                                                      url  class_id  \
# 2229   https://hamptoninn3.hilton.com/en/hotels/missi...         4
# 2230   https://hamptoninn3.hilton.com/en/hotels/missi...         4
# 2231   https://doubletree3.hilton.com/en/hotels/missi...         3
# 2232   https://hamptoninn3.hilton.com/en/hotels/missi...         4
# 2234   https://hamptoninn3.hilton.com/en/hotels/missi...         4
# ...                                                  ...       ...
# 18095  https://www.wyndhamhotels.com//laquinta/oxford...         4
# 18099  https://www.wyndhamhotels.com//laquinta/pearl-...         4
# 18110  https://www.wyndhamhotels.com//laquinta/starkv...         4
# 18114  https://www.wyndhamhotels.com//laquinta/tupelo...         4
# 18119  https://www.wyndhamhotels.com//laquinta/vicksb...         4
#
#                         category  \
# 2229   Limited-Service Mid-Scale
# 2230   Limited-Service Mid-Scale
# 2231      Full-Service Mid-Scale
# 2232   Limited-Service Mid-Scale
# 2234   Limited-Service Mid-Scale
# ...                          ...
# 18095  Limited-Service Mid-Scale
# 18099  Limited-Service Mid-Scale
# 18110  Limited-Service Mid-Scale
# 18114  Limited-Service Mid-Scale
# 18119  Limited-Service Mid-Scale
#
#                                             Bag_of_words  \
# 2229   Hilton Hampton Inn You can feel the Ole Miss p...
# 2230   Hilton Hampton Inn Our hotel is a three-minute...
# 2231   Hilton Doubletree Welcome to our beachfront ho...
# 2232   Hilton Hampton Inn Get ready for Biloxi Beach ...
# 2234   Hilton Hampton Inn Off I-110, our hotel near t...
# ...                                                  ...
# 18095  Wyndham La Quinta   A Bright Stay in Oxford   ...
# 18099  Wyndham La Quinta   The City with Soul   Pet-f...
# 18110  Wyndham La Quinta   A Bright Stay in Starkvill...
# 18114  Wyndham La Quinta   Southern Hospitality in Tu...
# 18119  Wyndham La Quinta   Visit Vicksburg   Inviting...
#
#                                                spacydocs  \
# 2229   Hilton Hampton Inn You can feel the Ole Miss p...
# 2230   Hilton Hampton Inn Our hotel is a three-minute...
# 2231   Hilton Doubletree Welcome to our beachfront ho...
# 2232   Hilton Hampton Inn Get ready for Biloxi Beach ...
# 2234   Hilton Hampton Inn Off I-110, our hotel near t...
# ...                                                  ...
# 18095  Wyndham La Quinta   A Bright Stay in Oxford   ...
# 18099  Wyndham La Quinta   The City with Soul   Pet-f...
# 18110  Wyndham La Quinta   A Bright Stay in Starkvill...
# 18114  Wyndham La Quinta   Southern Hospitality in Tu...
# 18119  Wyndham La Quinta   Visit Vicksburg   Inviting...
#
#                                                  vectors  \
# 2229   [0.112067401, 0.199603558, -0.0632298812, -0.1...
# 2230   [0.0932568833, 0.14844887, -0.0398839191, -0.1...
# 2231   [0.148159072, 0.145791903, 0.00234103319, -0.1...
# 2232   [0.088939704, 0.201280072, 0.0104636587, -0.11...
# 2234   [0.0938258469, 0.15931876, 0.0740400255, -0.16...
# ...                                                  ...
# 18095  [0.0618696809, 0.151404426, -0.0536890142, -0....
# 18099  [0.161509112, 0.157204762, -0.039605625, -0.07...
# 18110  [0.161504343, 0.169052765, 0.0162659157, -0.13...
# 18114  [0.160956323, 0.154107109, -0.00563816726, -0....
# 18119  [0.0918909982, 0.122472577, -0.00667067338, -0...
#
#                                              address              address2  \
# 2229            110 Heritage Drive, Oxford, MS 38655      Oxford, MS 38655
# 2230            103 Ed Perry Blvd., Oxford, MS 38655      Oxford, MS 38655
# 2231           940 Beach Boulevard, Biloxi, MS 39530      Biloxi, MS 39530
# 2232          1138 Beach Boulevard, Biloxi, MS 39530      Biloxi, MS 39530
# 2234    3828 Promenade Parkway, DIberville, MS 39540  DIberville, MS 39540
# ...                                              ...                   ...
# 18095           1171 Frontage Road, Oxford, MS 38655      Oxford, MS 38655
# 18099              501 S Pearson RD, Pearl, MS 39208       Pearl, MS 39208
# 18110          982 Hwy 12 East, Starkville, MS 39759  Starkville, MS 39759
# 18114           1013 N Gloster St., Tupelo, MS 38804      Tupelo, MS 38804
# 18119  4160 South Frontage Road, Vicksburg, MS 39180   Vicksburg, MS 39180
#
#        vectormean
# 2229     0.010692
# 2230     0.008752
# 2231     0.010049
# 2232     0.010911
# 2234     0.012352
# ...           ...
# 18095    0.009160
# 18099    0.011872
# 18110    0.010416
# 18114    0.008054
# 18119    0.011030
#
# [131 rows x 19 columns]

# %%
nlp = en_core_web_lg.load()
def convert_to_doc(user_input):
    doc = nlp(user_input)
    return doc

def vectorize_input(doc):
    return doc.vector

def similarity(user_input):
    
    # Convert user input to a spaCy doc
    user_input_doc = convert_to_doc(user_input)
    user_input_doc = vectorize_input(user_input_doc)
    

    
    # Calculate similarity with each hotel and create dicitonary of similarities and sentiments
    similarity_list = []
    
    for index, row in data.iterrows():
        similarity  = {}
#         doc = row['spacydocs']
        vectors = row['vectors']
        name = row['name']

        sim = user_input_doc
#         print(sim)
        similarity['name'] = name
        similarity['hotel_vectors'] = vectors
        similarity['input_vectors'] = sim
        similarity['similarity'] = cosine_similarity(vectors.reshape(1,-1), sim.reshape(1,-1))[0]
        similarity_list.append(similarity)
#         print(f'{type(vectors)} and {type(sim)}')
        
    return pd.DataFrame(similarity_list)

def top_ten(similarity_dict):    
    return similarity_dict.sort_values(by='similarity', ascending=False)

def recommend(user_input):
    similarity_dict =  similarity_and_sentiments(user_input)
    sentiment_list = top_ten(similarity_dict)
    final_recommendations = get_recommendations(sentiment_list, user_input)
    return final_recommendations

# %%
user_input = """I will be travelling to Biloxi, flying into the airport. I will visit the casinos as well as
            Mississippi Gulf Coast Community College. I will be here for an extended period of time. 
            I am a Hilton and Marriott rewards member, who enjoys breakfast and will be traveling with family."""

# %%
recs_1 = similarity(user_input)
recs_1[:10]
# Out:
#                                       name  \
# 0                  Hampton Inn Oxford-West
# 1     Hampton Inn Oxford/Conference Center
# 2        DoubleTree by Hilton Hotel Biloxi
# 3                       Hampton Inn Biloxi
# 4  Hampton Inn & Suites D'Iberville Biloxi
# 5         Hampton Inn Biloxi/Ocean Springs
# 6       Hilton Garden Inn Gulfport Airport
# 7             Hilton Garden Inn Pascagoula
# 8                   Hampton Inn Brookhaven
# 9              Hampton Inn & Suites McComb
#
#                                        hotel_vectors  \
# 0  [0.112067401, 0.199603558, -0.0632298812, -0.1...
# 1  [0.0932568833, 0.14844887, -0.0398839191, -0.1...
# 2  [0.148159072, 0.145791903, 0.00234103319, -0.1...
# 3  [0.088939704, 0.201280072, 0.0104636587, -0.11...
# 4  [0.0938258469, 0.15931876, 0.0740400255, -0.16...
# 5  [0.0683275163, 0.191422552, 0.0361849517, -0.0...
# 6  [0.144968092, 0.0936281756, 0.0402003489, -0.1...
# 7  [0.151753724, 0.16170752, -0.0509722121, -0.12...
# 8  [0.0835059062, 0.248919234, 0.00610671798, -0....
# 9  [0.0748368204, 0.219184831, -0.00640682876, -0...
#
#                                        input_vectors            similarity
# 0  [0.09296169, 0.11785219, -0.09615068, -0.16990...   [0.921856384010129]
# 1  [0.09296169, 0.11785219, -0.09615068, -0.16990...  [0.9152972094732186]
# 2  [0.09296169, 0.11785219, -0.09615068, -0.16990...  [0.9206805749813498]
# 3  [0.09296169, 0.11785219, -0.09615068, -0.16990...  [0.9289271911250674]
# 4  [0.09296169, 0.11785219, -0.09615068, -0.16990...  [0.9094216348421722]
# 5  [0.09296169, 0.11785219, -0.09615068, -0.16990...  [0.9224544204956181]
# 6  [0.09296169, 0.11785219, -0.09615068, -0.16990...  [0.9037066380121086]
# 7  [0.09296169, 0.11785219, -0.09615068, -0.16990...  [0.9149494686100418]
# 8  [0.09296169, 0.11785219, -0.09615068, -0.16990...  [0.9230793375319544]
# 9  [0.09296169, 0.11785219, -0.09615068, -0.16990...  [0.8938065164254689]

# %%
for index, row in data.iterrows():
    print(row['vectors'])
    print()
